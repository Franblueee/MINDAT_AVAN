# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import re
import tensorflow as tf
import pandas as pd
from skimage.io import imread
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import save_model, load_model
import seaborn as sns
sns.set_theme()

path_data = 'data/'
path_train='Sentinel2LULC_354/'
path_test='Test 2/'
#path_models='gdrive/MineriaIII/models/'
path_models='drive/MyDrive/MineriaIII/models/'
#path_pred='gdrive/MineriaIII/predictions/'
path_pred='drive/MyDrive/MineriaIII/predictions/'
ext_sub = '.csv'

# %%
label_groups = {1:1, 2:2, 3:3, 4:4,5:4, 6:5,7:5,8:5,9:5,10:5,11:5,12:5,13:5,14:5,15:5,16:5,17:5, 
                18:6,19:6,20:6, 21:7,22:7, 23:8, 24:9,25:9,26:9,27:9,28:9, 29:10}
subgroup = 9

# %%
data = []
labels = []

for d in os.listdir(path_data + path_train):
    lab = int(re.search('\d{1,2}', d).group())
    if label_groups.get(lab) == subgroup:
        for f in os.listdir(path_data + path_train + d):
            try:
                img = imread(path_data + path_train + d + '/' + f)
                data.append(img)
                labels.append(lab)
            except:
                print("Cannot read file: " + d + '/' + f)

data = np.array(data)
labels = np.array(labels)

# %%
test_data = []
test_labels = []

for f in os.listdir(path_data + path_test):
    lab = int(re.search('^(\d{1,2})_', f).group(1))
    if label_groups.get(lab) == subgroup:
        try:
            img = imread(path_data + path_test + f)
            test_data.append(img)
            test_labels.append(lab)
        except:
            print("Cannot read file: " + f)
            
test_data = np.array(test_data)
test_labels = np.array(test_labels)

# %%
#data = data.astype('float32')/255.0
#test_data = test_data.astype('float32')/255.0

data = tf.keras.applications.vgg19.preprocess_input(data)
test_data = tf.keras.applications.vgg19.preprocess_input(test_data)

# %%
nclasses = len(np.unique(labels))
img_shape = data.shape[1:4]
factor_labels = np.min(labels)

data_augmentation = tf.keras.Sequential([
      tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
      tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
      tf.keras.layers.experimental.preprocessing.RandomContrast(0.5)
  ])

# %%
batch_size = 64
shuffle_buffer_size = 1000

train, val = train_test_split(np.arange(len(labels)), test_size=0.01, random_state=48, stratify=labels)
train_data = data[train]
train_labels = labels[train]
val_data = data[val]
val_labels = labels[val]

if nclasses > 2:
  train_labels_coded = tf.one_hot(train_labels-factor_labels, depth=nclasses, on_value=1, off_value=0)
  val_labels_coded = tf.one_hot(val_labels-factor_labels, depth=nclasses, on_value=1, off_value=0)
  test_labels_coded = tf.one_hot(test_labels-factor_labels, depth=nclasses, on_value=1, off_value=0)
else:
  train_labels_coded = train_labels-factor_labels
  val_labels_coded = val_labels-factor_labels
  test_labels_coded = test_labels-factor_labels

train_dataset = tf.data.Dataset.from_tensor_slices((tf.convert_to_tensor(train_data), tf.convert_to_tensor(train_labels_coded)))
#train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x), y))
val_dataset = tf.data.Dataset.from_tensor_slices((tf.convert_to_tensor(val_data), tf.convert_to_tensor(val_labels_coded)))
test_dataset = tf.data.Dataset.from_tensor_slices((tf.convert_to_tensor(test_data), tf.convert_to_tensor(test_labels_coded)))

train_batches = train_dataset.shuffle(shuffle_buffer_size).batch(batch_size)
val_batches = val_dataset.batch(batch_size)
test_batches = test_dataset.batch(batch_size)

# %%
def create_model(binary=False):
  base_model = tf.keras.applications.vgg16.VGG16(include_top=False, weights='imagenet', input_shape=img_shape, pooling='avg')
  base_model.trainable = False
  if binary:  
    model = tf.keras.Sequential([
      base_model,
      tf.keras.layers.Dense(512, activation='relu'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(1, activation='sigmoid')
    ])
  else:
    model = tf.keras.Sequential([
      base_model,
      tf.keras.layers.Dense(512, activation='relu'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dropout(0.1),
      tf.keras.layers.Dense(nclasses)
    ])
  return model


def train_evaluate_model(model, name, binary=False, lr=0.0001):
  if binary:
    metric = 'binary_accuracy'
    metric_val = 'val_binary_accuracy' 
  else:
    metric = 'categorical_accuracy'
    metric_val = 'val_categorical_accuracy'

  earlystopping = tf.keras.callbacks.EarlyStopping(
    monitor=metric_val,
    verbose=1,
    mode='max',
    patience=10,
    restore_best_weights=True
  )
  epochs = 50
  optimizer = tf.keras.optimizers.Adam(learning_rate=lr, amsgrad=True)
  if binary:
    loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)
    metrics = [tf.keras.metrics.binary_accuracy]
  else:
    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    metrics = [tf.keras.metrics.categorical_accuracy]

  model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
  history = model.fit(train_batches,
                      epochs=epochs, 
                      validation_data=val_batches,
                      callbacks=[earlystopping])
  
  save_model(model, path_models + name + '.h5')

  evaluate_model(model, binary)


def train_evaluate_model2(model, name, binary=False, epochs=10, lr=0.0001):
  if binary:
    metric = 'binary_accuracy'
    metric_val = 'val_binary_accuracy' 
  else:
    metric = 'categorical_accuracy'
    metric_val = 'val_categorical_accuracy'

  optimizer = tf.keras.optimizers.Adam(learning_rate=lr, amsgrad=True)
  if binary:
    loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)
    metrics = [tf.keras.metrics.binary_accuracy]
  else:
    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    metrics = [tf.keras.metrics.categorical_accuracy]

  model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
  history = model.fit(train_batches,
                      epochs=epochs, 
                      validation_data=val_batches)
  
  save_model(model, path_models + name + '.h5')

  evaluate_model(model, binary)


def evaluate_model(model, binary=False):
  test_loss, test_acc = model.evaluate(test_batches)
  print('Test loss: ' + str(test_loss) + ', test acc: ' + str(test_acc))
  
  if binary:
    val_preds = (model.predict(val_data) > 0.5).astype(int)
    test_preds = (model.predict(test_data) > 0.5).astype(int)
  else:
    val_preds = np.argmax(model.predict(val_data), axis=-1)
    test_preds = np.argmax(model.predict(test_data), axis=-1)
  val_matrix = tf.math.confusion_matrix(val_labels-factor_labels, val_preds)
  test_matrix = tf.math.confusion_matrix(test_labels-factor_labels, test_preds)

  fig, ax = plt.subplots(1, 2, figsize=(20,8))
  axlabs = [str(l) for l in np.unique(np.sort(train_labels))]

  im = sns.heatmap(ax=ax[0], data=val_matrix, annot=True, fmt="d")
  ax[0].set_xticks(np.arange(nclasses))
  ax[0].set_yticks(np.arange(nclasses))
  ax[0].set_xticklabels(axlabs)
  ax[0].set_yticklabels(axlabs)
  ax[0].set_title("Validation conf matrix")

  im = sns.heatmap(ax=ax[1], data=test_matrix, annot=True, fmt="d")
  ax[1].set_xticks(np.arange(nclasses))
  ax[1].set_yticks(np.arange(nclasses))
  ax[1].set_xticklabels(axlabs)
  ax[1].set_yticklabels(axlabs)
  ax[1].set_title("Test confusion matrix")

  plt.show()
  
  
def prep_finetuning(model, from_layer):
  model.layers[0].trainable = True
  for layer in model.layers[0].layers[:from_layer]:
    layer.trainable =  False

# %%
model = create_model()
prep_finetuning(model, 0)
train_evaluate_model(model, 'crop_512-128_ft', lr=0.0001)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 65s 490ms/step - loss: 1.2191 - categorical_accuracy: 0.4922 - val_loss: 0.8168 - val_categorical_accuracy: 0.6836
# Epoch 2/50
# 100/100 [==============================] - 45s 447ms/step - loss: 0.8763 - categorical_accuracy: 0.6635 - val_loss: 0.8313 - val_categorical_accuracy: 0.6949
# Epoch 3/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.7574 - categorical_accuracy: 0.7150 - val_loss: 0.6205 - val_categorical_accuracy: 0.8079
# Epoch 4/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.6231 - categorical_accuracy: 0.7702 - val_loss: 0.7308 - val_categorical_accuracy: 0.7288
# Epoch 5/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.6411 - categorical_accuracy: 0.7633 - val_loss: 0.6071 - val_categorical_accuracy: 0.7401
# Epoch 6/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.5763 - categorical_accuracy: 0.7822 - val_loss: 0.7226 - val_categorical_accuracy: 0.7401
# Epoch 7/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.4800 - categorical_accuracy: 0.8211 - val_loss: 0.7083 - val_categorical_accuracy: 0.7514
# Epoch 8/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.4300 - categorical_accuracy: 0.8493 - val_loss: 0.5318 - val_categorical_accuracy: 0.8023
# Epoch 9/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.4679 - categorical_accuracy: 0.8481 - val_loss: 0.6420 - val_categorical_accuracy: 0.7797
# Epoch 10/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.4769 - categorical_accuracy: 0.8311 - val_loss: 0.5649 - val_categorical_accuracy: 0.8079
# Epoch 11/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.3891 - categorical_accuracy: 0.8644 - val_loss: 0.9976 - val_categorical_accuracy: 0.6158
# Epoch 12/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.4234 - categorical_accuracy: 0.8280 - val_loss: 0.7714 - val_categorical_accuracy: 0.7458
# Epoch 13/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.3825 - categorical_accuracy: 0.8575 - val_loss: 0.4792 - val_categorical_accuracy: 0.8249
# Epoch 14/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.3138 - categorical_accuracy: 0.8839 - val_loss: 0.4664 - val_categorical_accuracy: 0.8418
# Epoch 15/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.2585 - categorical_accuracy: 0.9140 - val_loss: 0.4735 - val_categorical_accuracy: 0.8249
# Epoch 16/50
# 100/100 [==============================] - 44s 444ms/step - loss: 0.2564 - categorical_accuracy: 0.9058 - val_loss: 0.5299 - val_categorical_accuracy: 0.8305
# Epoch 17/50
# 100/100 [==============================] - 45s 444ms/step - loss: 0.2454 - categorical_accuracy: 0.9134 - val_loss: 0.4084 - val_categorical_accuracy: 0.8192
# Epoch 18/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.2079 - categorical_accuracy: 0.9372 - val_loss: 0.4679 - val_categorical_accuracy: 0.8531
# Epoch 19/50
# 100/100 [==============================] - 44s 445ms/step - loss: 0.2041 - categorical_accuracy: 0.9253 - val_loss: 0.3231 - val_categorical_accuracy: 0.8870
# Epoch 20/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.1775 - categorical_accuracy: 0.9429 - val_loss: 0.4921 - val_categorical_accuracy: 0.8362
# Epoch 21/50
# 100/100 [==============================] - 45s 444ms/step - loss: 0.1770 - categorical_accuracy: 0.9397 - val_loss: 0.4623 - val_categorical_accuracy: 0.8531
# Epoch 22/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.1196 - categorical_accuracy: 0.9592 - val_loss: 0.6367 - val_categorical_accuracy: 0.8079
# Epoch 23/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.1663 - categorical_accuracy: 0.9429 - val_loss: 0.7579 - val_categorical_accuracy: 0.7684
# Epoch 24/50
# 100/100 [==============================] - 45s 444ms/step - loss: 0.1934 - categorical_accuracy: 0.9303 - val_loss: 0.4163 - val_categorical_accuracy: 0.8418
# Epoch 25/50
# 100/100 [==============================] - 44s 444ms/step - loss: 0.1446 - categorical_accuracy: 0.9567 - val_loss: 0.4532 - val_categorical_accuracy: 0.8757
# Epoch 26/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.1261 - categorical_accuracy: 0.9611 - val_loss: 0.5340 - val_categorical_accuracy: 0.8757
# Epoch 27/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0972 - categorical_accuracy: 0.9661 - val_loss: 0.7214 - val_categorical_accuracy: 0.8418
# Epoch 28/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.1210 - categorical_accuracy: 0.9642 - val_loss: 0.5859 - val_categorical_accuracy: 0.8475
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 0.1236 - categorical_accuracy: 0.9636Restoring model weights from the end of the best epoch: 19.
# 100/100 [==============================] - 45s 446ms/step - loss: 0.1236 - categorical_accuracy: 0.9636 - val_loss: 0.3970 - val_categorical_accuracy: 0.8644
# Epoch 29: early stopping
# 18/18 [==============================] - 4s 227ms/step - loss: 0.2326 - categorical_accuracy: 0.9137
# Test loss: 0.23263099789619446, test acc: 0.9136690497398376

# %%
train_evaluate_model(model, 'crop_512-128_ft_v2', lr=0.00001)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 46s 448ms/step - loss: 0.1219 - categorical_accuracy: 0.9586 - val_loss: 0.0784 - val_categorical_accuracy: 0.9831
# Epoch 2/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0897 - categorical_accuracy: 0.9724 - val_loss: 0.0613 - val_categorical_accuracy: 0.9831
# Epoch 3/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0662 - categorical_accuracy: 0.9774 - val_loss: 0.0773 - val_categorical_accuracy: 0.9718
# Epoch 4/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0509 - categorical_accuracy: 0.9799 - val_loss: 0.0618 - val_categorical_accuracy: 0.9718
# Epoch 5/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0447 - categorical_accuracy: 0.9862 - val_loss: 0.0447 - val_categorical_accuracy: 0.9831
# Epoch 6/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0267 - categorical_accuracy: 0.9912 - val_loss: 0.0675 - val_categorical_accuracy: 0.9718
# Epoch 7/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0183 - categorical_accuracy: 0.9950 - val_loss: 0.0805 - val_categorical_accuracy: 0.9774
# Epoch 8/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0231 - categorical_accuracy: 0.9925 - val_loss: 0.0383 - val_categorical_accuracy: 0.9887
# Epoch 9/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0294 - categorical_accuracy: 0.9931 - val_loss: 0.1322 - val_categorical_accuracy: 0.9548
# Epoch 10/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0183 - categorical_accuracy: 0.9918 - val_loss: 0.0971 - val_categorical_accuracy: 0.9774
# Epoch 11/50
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0063 - categorical_accuracy: 0.9981 - val_loss: 0.0795 - val_categorical_accuracy: 0.9774
# Epoch 12/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0043 - categorical_accuracy: 0.9994 - val_loss: 0.0664 - val_categorical_accuracy: 0.9774
# Epoch 13/50
# 100/100 [==============================] - 45s 447ms/step - loss: 0.0035 - categorical_accuracy: 0.9994 - val_loss: 0.0628 - val_categorical_accuracy: 0.9718
# Epoch 14/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0026 - categorical_accuracy: 0.9994 - val_loss: 0.0780 - val_categorical_accuracy: 0.9774
# Epoch 15/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.0756 - val_categorical_accuracy: 0.9774
# Epoch 16/50
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - val_loss: 0.0816 - val_categorical_accuracy: 0.9774
# Epoch 17/50
# 100/100 [==============================] - 45s 445ms/step - loss: 7.5371e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0830 - val_categorical_accuracy: 0.9774
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 6.3247e-04 - categorical_accuracy: 1.0000Restoring model weights from the end of the best epoch: 8.
# 100/100 [==============================] - 45s 446ms/step - loss: 6.3247e-04 - categorical_accuracy: 1.0000 - val_loss: 0.0715 - val_categorical_accuracy: 0.9831
# Epoch 18: early stopping
# 18/18 [==============================] - 3s 156ms/step - loss: 0.1364 - categorical_accuracy: 0.9640
# Test loss: 0.1364346295595169, test acc: 0.9640287756919861

# %%
train_evaluate_model(model, 'crop_512-128_ft_v3', lr=0.000001)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 56s 983ms/step - loss: 0.0171 - categorical_accuracy: 0.9956 - val_loss: 0.0193 - val_categorical_accuracy: 0.9944
# Epoch 2/50
# 50/50 [==============================] - 42s 840ms/step - loss: 0.0122 - categorical_accuracy: 0.9975 - val_loss: 0.0198 - val_categorical_accuracy: 0.9944
# Epoch 3/50
# 50/50 [==============================] - 42s 842ms/step - loss: 0.0112 - categorical_accuracy: 0.9981 - val_loss: 0.0208 - val_categorical_accuracy: 0.9944
# Epoch 4/50
# 50/50 [==============================] - 42s 838ms/step - loss: 0.0096 - categorical_accuracy: 0.9981 - val_loss: 0.0209 - val_categorical_accuracy: 0.9944
# Epoch 5/50
# 50/50 [==============================] - 42s 841ms/step - loss: 0.0077 - categorical_accuracy: 0.9981 - val_loss: 0.0213 - val_categorical_accuracy: 0.9944
# Epoch 6/50
# 50/50 [==============================] - 42s 840ms/step - loss: 0.0069 - categorical_accuracy: 0.9987 - val_loss: 0.0217 - val_categorical_accuracy: 0.9944
# Epoch 7/50
# 50/50 [==============================] - 42s 840ms/step - loss: 0.0079 - categorical_accuracy: 0.9987 - val_loss: 0.0225 - val_categorical_accuracy: 0.9944
# Epoch 8/50
# 50/50 [==============================] - 42s 844ms/step - loss: 0.0065 - categorical_accuracy: 0.9987 - val_loss: 0.0227 - val_categorical_accuracy: 0.9944
# Epoch 9/50
# 50/50 [==============================] - 42s 839ms/step - loss: 0.0057 - categorical_accuracy: 0.9981 - val_loss: 0.0236 - val_categorical_accuracy: 0.9944
# Epoch 10/50
# 50/50 [==============================] - 42s 838ms/step - loss: 0.0057 - categorical_accuracy: 0.9987 - val_loss: 0.0238 - val_categorical_accuracy: 0.9944
# Epoch 11/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0059 - categorical_accuracy: 0.9987Restoring model weights from the end of the best epoch: 1.
# 50/50 [==============================] - 42s 841ms/step - loss: 0.0059 - categorical_accuracy: 0.9987 - val_loss: 0.0238 - val_categorical_accuracy: 0.9944
# Epoch 11: early stopping
# 9/9 [==============================] - 3s 274ms/step - loss: 0.1060 - categorical_accuracy: 0.9784
# Test loss: 0.10603249073028564, test acc: 0.9784172773361206

# %%
train_evaluate_model(model, 'crop_512-128_ft_v4', lr=0.000001)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 44s 849ms/step - loss: 0.0137 - categorical_accuracy: 0.9969 - val_loss: 0.0223 - val_categorical_accuracy: 0.9944
# Epoch 2/50
# 50/50 [==============================] - 42s 842ms/step - loss: 0.0113 - categorical_accuracy: 0.9975 - val_loss: 0.0226 - val_categorical_accuracy: 0.9944
# Epoch 3/50
# 50/50 [==============================] - 42s 841ms/step - loss: 0.0081 - categorical_accuracy: 0.9981 - val_loss: 0.0233 - val_categorical_accuracy: 0.9944
# Epoch 4/50
# 50/50 [==============================] - 42s 842ms/step - loss: 0.0096 - categorical_accuracy: 0.9975 - val_loss: 0.0236 - val_categorical_accuracy: 0.9944
# Epoch 5/50
# 50/50 [==============================] - 42s 842ms/step - loss: 0.0082 - categorical_accuracy: 0.9969 - val_loss: 0.0240 - val_categorical_accuracy: 0.9944
# Epoch 6/50
# 50/50 [==============================] - 42s 843ms/step - loss: 0.0081 - categorical_accuracy: 0.9981 - val_loss: 0.0247 - val_categorical_accuracy: 0.9944
# Epoch 7/50
# 50/50 [==============================] - 42s 838ms/step - loss: 0.0066 - categorical_accuracy: 0.9987 - val_loss: 0.0254 - val_categorical_accuracy: 0.9944
# Epoch 8/50
# 50/50 [==============================] - 42s 841ms/step - loss: 0.0056 - categorical_accuracy: 0.9987 - val_loss: 0.0258 - val_categorical_accuracy: 0.9944
# Epoch 9/50
# 50/50 [==============================] - 42s 841ms/step - loss: 0.0062 - categorical_accuracy: 0.9987 - val_loss: 0.0267 - val_categorical_accuracy: 0.9944
# Epoch 10/50
# 50/50 [==============================] - 42s 839ms/step - loss: 0.0045 - categorical_accuracy: 0.9987 - val_loss: 0.0272 - val_categorical_accuracy: 0.9944
# Epoch 11/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0046 - categorical_accuracy: 0.9987Restoring model weights from the end of the best epoch: 1.
# 50/50 [==============================] - 42s 844ms/step - loss: 0.0046 - categorical_accuracy: 0.9987 - val_loss: 0.0273 - val_categorical_accuracy: 0.9944
# Epoch 11: early stopping
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0934 - categorical_accuracy: 0.9856
# Test loss: 0.09337937831878662, test acc: 0.9856114983558655

# %%
modelv4 = load_model(path_models + 'crop_512-128_ft_v4.h5')
train_evaluate_model2(modelv4, 'crop_512-128_ft_v5', lr=0.00001)
# Out:
# Epoch 1/10
# 28/28 [==============================] - 49s 2s/step - loss: 0.0138 - categorical_accuracy: 0.9960 - val_loss: 0.0052 - val_categorical_accuracy: 1.0000
# Epoch 2/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0092 - categorical_accuracy: 0.9977 - val_loss: 0.0052 - val_categorical_accuracy: 1.0000
# Epoch 3/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0063 - categorical_accuracy: 0.9983 - val_loss: 9.3059e-04 - val_categorical_accuracy: 1.0000
# Epoch 4/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0053 - categorical_accuracy: 0.9983 - val_loss: 0.0025 - val_categorical_accuracy: 1.0000
# Epoch 5/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0040 - categorical_accuracy: 0.9989 - val_loss: 8.3499e-04 - val_categorical_accuracy: 1.0000
# Epoch 6/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0026 - categorical_accuracy: 0.9994 - val_loss: 4.7803e-04 - val_categorical_accuracy: 1.0000
# Epoch 7/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.0029 - val_categorical_accuracy: 1.0000
# Epoch 8/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0024 - categorical_accuracy: 0.9989 - val_loss: 0.0015 - val_categorical_accuracy: 1.0000
# Epoch 9/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 3.1454e-04 - val_categorical_accuracy: 1.0000
# Epoch 10/10
# 28/28 [==============================] - 46s 2s/step - loss: 0.0011 - categorical_accuracy: 0.9994 - val_loss: 2.6996e-04 - val_categorical_accuracy: 1.0000
# 5/5 [==============================] - 3s 469ms/step - loss: 0.1042 - categorical_accuracy: 0.9892
# Test loss: 0.10419207066297531, test acc: 0.9892086386680603
