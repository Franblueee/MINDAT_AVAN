# %%
#!add-apt-repository ppa:alessandro-strada/ppa
#!apt-get update
#!apt-get install google-drive-ocamlfuse

# %%
#!google-drive-ocamlfuse -headless -id 756536264233-g1eqirc1ndsou3c6es3b07eqdv0qopf5.apps.googleusercontent.com -secret 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

# %%
#!mkdir -p gdrive
#!google-drive-ocamlfuse gdrive
#!umount gdrive

# %%
train_zip = 'gdrive/MineriaIII/Sentinel2LULC_354.zip'
test_zip = 'gdrive/MineriaIII/Test2.zip'
path_data = 'data/'

#!mkdir -p data
#!unzip $train_zip -d $path_data
#!unzip $test_zip -d $path_data
